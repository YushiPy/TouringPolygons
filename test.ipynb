# %% [markdown]
# ## Setup

# %%
import traceback
from typing import Iterable, Sequence
from vector2 import Vector2
from polygon2 import Polygon2

from problem2_draw import Drawing

type CanVector = Sequence[float] | Vector2
type CanPolygon = Iterable[CanVector]
type Test = tuple[CanVector, CanVector, Iterable[CanPolygon], Iterable[CanPolygon]]

def do_test(start: CanVector, end: CanVector, polygons: Iterable[CanPolygon], fences: Iterable[CanPolygon]) -> None:
	"""
	Test the drawing functionality with given start and end points, polygons, and expected output.
	"""

	_start = Vector2(*start)
	_end = Vector2(*end)

	_polygons = [Polygon2(polygon) for polygon in polygons]
	_fences = [Polygon2(fence) for fence in fences]

	drawing = Drawing(_start, _end, _polygons, _fences)
	
	try: 
		drawing.shortest_path()
	except ValueError:
		traceback.print_exc()

	drawing.draw()

def parse_test(values: list[list[tuple[float, float]]]) -> Test:
	"""
	Parse a list of values into a Test tuple.
	"""

	ones = [i for i in values if len(i) == 1]
	values = [i for i in values if len(i) > 1]

	start = ones[0][0]
	end = ones[1][0]
	
	polygons = values[1::2]
	fences = values[::2]

	return start, end, polygons, fences

# %% [markdown]
# ## Tests

# %%
x = [
	[(0.0, 4.0)],
	[(-6.0, 5.0), (-6.0, 1.0), (-1.0, 1.0), (-6.0, -0.0), (-6.0, -3.0), (6.0, -3.0), (6.0, -0.0), (1.0, 1.0), (6.0, 1.0), (6.0, 5.0)],
	[(-3.0, -0.0), (3.0, -0.0), (0.0, -1.0)],
	[(4.0, -3.5)],
	[(-7.0, 2.0), (7.0, 2.0), (7.0, -4.0), (-7.0, -4.0)],
]

do_test(*parse_test(x))
# Out:
# []

# %%
x = [
	[(0.0, 4.0)],
	[(-0.0, 4.0), (-1.0, 1.0), (-3.0, -0.0), (-0.0, -1.0), (3.0, -0.0), (1.0, 1.0)],
	[(-3.0, -0.0), (3.0, -0.0), (0.0, -1.0)],
	[(4.0, -3.5)],
	[(-3.0, 0.0), (4.0, -3.5), (3.0, 0.0)],
]

do_test(*parse_test(x))
# Out:
# []

# %%
x = [
	[(0.0, 13.333)],
	[(-16.667, 16.667), (-16.667, 3.333), (-3.333, 3.333), (-16.667, -0.0), (-16.667, -13.333), (23.333, -13.333), (23.333, -0.0), (6.667, 3.333), (23.333, 3.333), (23.333, 13.333), (7.133, 9.767), (16.667, 16.667)],
	[(-6.667, -0.0), (3.333, -3.333), (13.333, -0.0)],
	[(-23.333, 10.0), (-20.0, 6.667), (-13.333, 20.0), (-13.333, 6.667), (-10.0, 26.667), (0.0, 23.333), (-3.333, 13.333), (6.667, 20.0), (10.0, 26.667), (10.0, 13.333), (16.667, 23.333), (23.333, 20.0), (16.667, 13.333), (26.667, 6.667), (6.667, 6.667), (26.667, 3.333), (16.667, -3.333), (0.0, -6.667), (26.667, -3.333), (26.667, -10.0), (3.333, -10.0), (23.333, -16.667), (-23.333, -20.0), (-26.667, -13.333), (-10.0, -6.667), (-16.667, -16.667), (-3.333, -6.667), (-26.667, 3.333)],

# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 10
#       1 x = [
#       2 	[(0.0, 13.333)],
#       3 	[(-16.667, 16.667), (-16.667, 3.333), (-3.333, 3.333), (-16.667, -0.0), (-16.667, -13.333), (23.333, -13.333), (23.333, -0.0), (6.667, 3.333), (23.333, 3.333), (23.333, 13.333), (7.133, 9.767), (16.667, 16.667)],
#    (...)      7 	[(12.0, -5.0), (-12.0, -3.0), (14.0, -20.0), (22.0, -1.0)],
#       8 ]
# ---> 10 do_test(*parse_test(x))
#
# Cell In[2], line 41, in parse_test(values)
#      38 values = [i for i in values if len(i) > 1]
#      40 start = ones[0][0]
# ---> 41 end = ones[1][0]
#      43 polygons = values[1::2]
#      44 fences = values[::2]
#
# IndexError: list index out of range

# %%
x = [
	[(0.0, 4.009)],
	[(-4.593, 4.593), (-4.593, 0.919), (-0.919, 0.919), (-4.593, -0.0), (-4.593, -3.674), (6.43, -3.674), (6.43, -0.0), (1.837, 0.919), (6.43, 0.919), (6.43, 3.674), (1.837, 2.756), (4.593, 4.593)],
	[(-1.837, -0.0), (0.919, -0.919), (3.674, -0.0), (2.185, 0.381), (0.401, 0.521), (-1.102, 0.241)],
	[(-6.43, 2.756), (-5.511, 1.837), (-3.674, 5.511), (-3.674, 1.837), (-2.756, 7.349), (0.0, 6.43), (-0.919, 3.674), (1.837, 5.511), (2.756, 7.349), (2.756, 3.674), (4.593, 6.43), (6.43, 5.511), (4.593, 3.674), (7.349, 1.837), (1.837, 1.837), (7.349, 0.919), (4.593, -0.919), (0.0, -1.837), (7.349, -0.919), (7.349, -2.756), (1.002, -3.007), (6.43, -4.593), (-6.43, -5.511), (-7.349, -3.674), (-2.756, -1.837), (-4.593, -4.593), (-0.919, -1.837), (-7.349, 0.919)],
	[(-5.511, -3.674), (-4.593, -2.756), (-3.674, -2.756), (-4.593, -3.674)],
	[(-5.511, -1.837), (-8.267, -4.593), (-3.674, -6.43), (0.919, -2.756), (-3.674, -5.511), (-5.511, -4.593)],
	[(-1.837, -4.593)],
]

print(parse_test(x))

do_test(*parse_test(x))
# Out:
# ((0.0, 4.009), (-1.837, -4.593), [[(-1.837, -0.0), (0.919, -0.919), (3.674, -0.0), (2.185, 0.381), (0.401, 0.521), (-1.102, 0.241)], [(-5.511, -3.674), (-4.593, -2.756), (-3.674, -2.756), (-4.593, -3.674)]], [[(-4.593, 4.593), (-4.593, 0.919), (-0.919, 0.919), (-4.593, -0.0), (-4.593, -3.674), (6.43, -3.674), (6.43, -0.0), (1.837, 0.919), (6.43, 0.919), (6.43, 3.674), (1.837, 2.756), (4.593, 4.593)], [(-6.43, 2.756), (-5.511, 1.837), (-3.674, 5.511), (-3.674, 1.837), (-2.756, 7.349), (0.0, 6.43), (-0.919, 3.674), (1.837, 5.511), (2.756, 7.349), (2.756, 3.674), (4.593, 6.43), (6.43, 5.511), (4.593, 3.674), (7.349, 1.837), (1.837, 1.837), (7.349, 0.919), (4.593, -0.919), (0.0, -1.837), (7.349, -0.919), (7.349, -2.756), (1.002, -3.007), (6.43, -4.593), (-6.43, -5.511), (-7.349, -3.674), (-2.756, -1.837), (-4.593, -4.593), (-0.919, -1.837), (-7.349, 0.919)], [(-5.511, -1.837), (-8.267, -4.593), (-3.674, -6.43), (0.919, -2.756), (-3.674, -5.511), (-5.511, -4.593)]])
# (-0.919, -1.837) (-0.919, 0.919) (-4.593, 0.919) (-4.593, -0.0) (0.0, 4.009)
# (-0.919, -1.837) (-0.919, 0.919) (-0.919, 0.275092)
# [(Vector2(-0.919, -1.837), Vector2(-0.919, 0.919)), (Vector2(-4.593, -4.593), Vector2(-0.919, -1.837)), (Vector2(1.002, -3.007), Vector2(-0.919, -1.837)), (Vector2(0.0, -1.837), Vector2(-0.919, 0.919)), (Vector2(1.837, 1.837), Vector2(inf, inf)), (Vector2(4.593, 3.674), Vector2(inf, inf)), (Vector2(2.756, 3.674), Vector2(inf, inf)), (Vector2(1.837, 5.511), Vector2(inf, inf)), (Vector2(-0.919, 3.674), Vector2(inf, inf)), (Vector2(-3.674, 1.837), Vector2(inf, inf)), (Vector2(-5.511, 1.837), Vector2(inf, inf))]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 13
#       1 x = [
#       2 	[(0.0, 4.009)],
#       3 	[(-4.593, 4.593), (-4.593, 0.919), (-0.919, 0.919), (-4.593, -0.0), (-4.593, -3.674), (6.43, -3.674), (6.43, -0.0), (1.837, 0.919), (6.43, 0.919), (6.43, 3.674), (1.837, 2.756), (4.593, 4.593)],
#    (...)      8 	[(-1.837, -4.593)],
#       9 ]
#      11 print(parse_test(x))
# ---> 13 do_test(*parse_test(x))
#
# Cell In[2], line 30, in do_test(start, end, polygons, fences)
#      27 except ValueError:
#      28 	traceback.print_exc()
# ---> 30 drawing.draw()
#
# File ~/Documents/Documents-Gabriel/Scripts/TouringPolygons/problem2_draw.py:172, in Drawing.draw(self, scenes)
#     169 flat = axs.flatten() if count > 1 else [axs]
#     171 for i, a in enumerate(scenes):
# --> 172 	self.draw_scene(flat[i + 1], a)
#     173 	flat[i + 1].set_title(f"Regions for polygon {a + 1}", fontsize=14)
#     175 for i in range(count, len(flat)):
#
# File ~/Documents/Documents-Gabriel/Scripts/TouringPolygons/problem2_draw.py:281, in Drawing.draw_scene(self, ax, index)
#     279 if 0 <= index < len(self.polygons):
#     280 	polygon = self.polygons[index]
# --> 281 	draw_cones()
#     282 	draw_edges()
#     284 for i, polygon in enumerate(self.polygons):
#
# File ~/Documents/Documents-Gabriel/Scripts/TouringPolygons/problem2_draw.py:226, in Drawing.draw_scene.<locals>.draw_cones()
#     222 for i in range(len(polygon)):
#     224 	vertex = polygon[i]
# --> 226 	ray1, ray2 = self.cones[index][i]
#     228 	if ray1 == ray2:
#     229 		continue
#
# IndexError: list index out of range
