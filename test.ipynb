# %%
from vector2 import Vector2
from polygon2 import Polygon2

from problem2_draw import Drawing

start = Vector2(0, 1)
end = Vector2(0, -3.5)

polygons = [
	Polygon2([
		Vector2(-2, -1), Vector2(2, -1), Vector2(0, -2)
	])
]

fences = [
	Polygon2([
		Vector2(-4, 2), Vector2(-4, 1), Vector2(-0.3, 0), Vector2(-4, 0), 
		Vector2(-0.3, -0.5), Vector2(-4, -1), Vector2(-4, -2), Vector2(-0.3, -2),
		Vector2(-4, -3),
		Vector2(4, -3), Vector2(4, 0), Vector2(0.3, 0), Vector2(4, 1), Vector2(4, 2),
	]),
	Polygon2([
		Vector2(-3, -0.5), Vector2(-3, -4), Vector2(3, -4), Vector2(3, -3), Vector2(0, -2.5), Vector2(3, -2), Vector2(3, -0.5)
	])
]

solution = Drawing(start, end, polygons, fences)
solution.shortest_path()
solution.draw()
# Out:
# Path from (0, 1) to (0, -2.5) is optimal, reaching polygon 0 at (0.0, -1.0)
# (0, 1)

# %%
"""
from vector2 import Vector2
from polygon2 import Polygon2

from problem2_draw import Drawing

start = Vector2(-3, 0)
end = Vector2(3, 0)

polygons = [
	Polygon2([Vector2(-1, 1), Vector2(1, 1), Vector2(0, 2)]),
	Polygon2([Vector2(-1, 3), Vector2(1, 4), Vector2(1, 6), Vector2(-1, 5)]),
]

fences = [
	Polygon2([Vector2(-4, 3), Vector2(-3, -1), Vector2(-2, 0.3), Vector2(-1, -1), Vector2(2, 0), Vector2(2, 2)]),
	Polygon2([Vector2(-2, 6), Vector2(2, 8), Vector2(2, 4), Vector2(0, 3), Vector2(3, -1), Vector2(2, -1), Vector2(-1, -1)]),
	Polygon2([Vector2(-2, 7), Vector2(2, 7), Vector2(0, 0), Vector2(4, 2), Vector2(3, -1), Vector2(2, 0), Vector2(-1, -1)]),
]

drawing = Drawing(start, end, polygons, fences)

# drawing.shortest_path()

try:drawing.shortest_path()
except: pass
drawing.draw([0])
"""
# Out:
# '\nfrom vector2 import Vector2\nfrom polygon2 import Polygon2\n\nfrom problem2_draw import Drawing\n\nstart = Vector2(-3, 0)\nend = Vector2(3, 0)\n\npolygons = [\n\tPolygon2([Vector2(-1, 1), Vector2(1, 1), Vector2(0, 2)]),\n\tPolygon2([Vector2(-1, 3), Vector2(1, 4), Vector2(1, 6), Vector2(-1, 5)]),\n]\n\nfences = [\n\tPolygon2([Vector2(-4, 3), Vector2(-3, -1), Vector2(-2, 0.3), Vector2(-1, -1), Vector2(2, 0), Vector2(2, 2)]),\n\tPolygon2([Vector2(-2, 6), Vector2(2, 8), Vector2(2, 4), Vector2(0, 3), Vector2(3, -1), Vector2(2, -1), Vector2(-1, -1)]),\n\tPolygon2([Vector2(-2, 7), Vector2(2, 7), Vector2(0, 0), Vector2(4, 2), Vector2(3, -1), Vector2(2, 0), Vector2(-1, -1)]),\n]\n\ndrawing = Drawing(start, end, polygons, fences)\n\n# drawing.shortest_path()\n\ntry:drawing.shortest_path()\nexcept: pass\ndrawing.draw([0])\n'
